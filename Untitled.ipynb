# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
data=pd.read_csv("titles.csv")

# %%
data.head(5)
# Out:
#          id                  title   type  \
# 0   tm87233  It's a Wonderful Life  MOVIE
# 1  tm143047              Duck Soup  MOVIE
# 2   tm83884        His Girl Friday  MOVIE
# 3   ts20945      The Three Stooges   SHOW
# 4    tm5012              Red River  MOVIE
#
#                                          description  release_year  \
# 0  A holiday favourite for generations...  George...          1946
# 1  Rufus T. Firefly is named president/dictator o...          1933
# 2  Hildy, the journalist former wife of newspaper...          1940
# 3  The Three Stooges were an American vaudeville ...          1934
# 4  Headstrong Thomas Dunson starts a thriving Tex...          1948
#
#   age_certification  runtime  \
# 0                PG      130
# 1               NaN       69
# 2               NaN       92
# 3             TV-PG       19
# 4               NaN      133
#
#                                               genres production_countries  \
# ...

# %%
data.tail(5)
# Out:
#               id                               title   type  \
# 10868  tm1292884                                Hunt  MOVIE
# 10869  tm1284753                  Ennalum Ente Aliya  MOVIE
# 10870  tm1303380  Anubhav Singh Bassi: Bas Kar Bassi  MOVIE
# 10871  tm1307408     Pinkfong! Summer in Wonderville  MOVIE
# 10872  tm1297385                            Chapelle  MOVIE
#
#                                              description  release_year  \
# 10868  Arjun is the ACP of Hyderabad, who gets involv...          2023
# 10869  It tells the story of a teen girl from a Musli...          2023
# 10870  Fresh out of national law university, Bassi ar...          2023
# 10871  It’s a hot summer day in Wonderville! Let’s jo...          2023
# 10872  In the streets of North Paris, in a famous ghe...          2023
#
#       age_certification  runtime                           genres  \
# 10868               NaN      129  ['action', 'thriller', 'crime']
# ...

# %%
data.shape
# Out:
# (10873, 15)

# %%
data.size
# Out:
# 163095

# %%
data.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10873 entries, 0 to 10872
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10873 non-null  object
#  1   title                 10873 non-null  object
#  2   type                  10873 non-null  object
#  3   description           10729 non-null  object
#  4   release_year          10873 non-null  int64
#  5   age_certification     3688 non-null   object
#  6   runtime               10873 non-null  int64
#  7   genres                10873 non-null  object
#  8   production_countries  10873 non-null  object
#  9   seasons               1551 non-null   float64
#  10  imdb_id               10172 non-null  object
#  11  imdb_score            9765 non-null   float64
#  12  imdb_votes            9753 non-null   float64
#  13  tmdb_popularity       10302 non-null  float64
#  14  tmdb_score            8747 non-null   float64
# ...

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %% [markdown]
# #no duplicate in the dataset

# %% [markdown]
# # Null Values

# %%
data.isnull()
# Out:
#           id  title   type  description  release_year  age_certification  \
# 0      False  False  False        False         False              False
# 1      False  False  False        False         False               True
# 2      False  False  False        False         False               True
# 3      False  False  False        False         False              False
# 4      False  False  False        False         False               True
# ...      ...    ...    ...          ...           ...                ...
# 10868  False  False  False        False         False               True
# 10869  False  False  False        False         False               True
# 10870  False  False  False        False         False               True
# 10871  False  False  False        False         False               True
# 10872  False  False  False        False         False               True
#
#        runtime  genres  production_countries  seasons  imdb_id  imdb_score  \
# ...

# %%
data.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              144
# release_year               0
# age_certification       7185
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 9322
# imdb_id                  701
# imdb_score              1108
# imdb_votes              1120
# tmdb_popularity          571
# tmdb_score              2126
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Year in which highest number of Tv Shows and Movies are released

# %%
data.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
data.drop([8374],axis=0,inplace=True)

# %%
mask=data['release_year']>2000
data1=data[mask]
data1['release_year'].value_counts().sort_values(ascending=False)
# Out:
# 2021    1140
# 2020     878
# 2019     863
# 2018     757
# 2017     618
# 2022     540
# 2016     520
# 2014     391
# 2015     389
# 2013     353
# 2012     272
# 2011     244
# 2010     198
# 2008     183
# 2009     168
# 2007     135
# 2006     127
# 2004     108
# 2005     102
# 2001      91
# 2002      83
# 2003      76
# 2023      55
# Name: release_year, dtype: int64

# %%
data1['release_year'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Movies and Tv Shows in the dataset

# %%
data.groupby('type').type.count()
# Out:
# type
# MOVIE    9321
# SHOW     1551
# Name: type, dtype: int64

# %%
sns.catplot(x='type',kind='count',data=data,palette='BuGn')

# %% [markdown]
# # Most pouplar movies and shows produced in India after 2000

# %%
filt=data1['production_countries'].str.contains('IN', na=False)
data2=data1.loc[filt]

# %% [markdown]
# # Most popular movies

# %%
data3=data2[((data2['imdb_score']>=8.0)&(data2['tmdb_score']>=8.0)) & (data2['type']=='MOVIE')].sort_values('imdb_score',ascending=False)
data3[['title','imdb_score','tmdb_score']].head(5)
# Out:
#                            title  imdb_score  tmdb_score
# 6733           Pariyerum Perumal         8.7         8.1
# 5028                   Pitruroon         8.5         9.0
# 6898   Zakir Khan: Haq Se Single         8.5         8.1
# 9898                Sher Shivraj         8.4         9.5
# 10416                    Jayanti         8.3        10.0

# %% [markdown]
# # Most polpular Shows

# %%
data4=data2[((data2['imdb_score']>=8.0) & (data2['tmdb_score']>=8.0)) & (data2['type']=='SHOW')].sort_values('imdb_score',ascending=False)
data4[['title','imdb_score','tmdb_score']].head(5)
# Out:
#              title  imdb_score  tmdb_score
# 7710     Panchayat         8.9         8.2
# 7552      ImMATURE         8.7         8.9
# 6092      Mirzapur         8.5         8.0
# 10825        Farzi         8.5         8.0
# 9321   Jugaadistan         8.4         8.0

# %%
# Out:
#                   0            1            2           3           4     5  \
# 2581      ['comedy'     'drama']         None        None        None  None
# 2582      ['drama']         None         None        None        None  None
# 2583       ['drama'     'comedy'     'crime']        None        None  None
# 2584       ['drama'      'scifi'   'romance']        None        None  None
# 2585   ['animation'    'fantasy'     'family'   'romance'   'comedy']  None
# ...             ...          ...          ...         ...         ...   ...
# 10868     ['action'   'thriller'     'crime']        None        None  None
# 10869      ['drama'    'comedy']         None        None        None  None
# 10870    ['comedy']         None         None        None        None  None
# 10871            []         None         None        None        None  None
# 10872     ['drama']         None         None        None        None  None
#
#           6     7     8
# 2581   None  None  None
# ...

# %%
data1['age_certification'].nunique()
# Out:
# 12

# %%
data1['age_certification'].unique()
# Out:
# array(['TV-MA', 'TV-14', 'TV-PG', 'R', 'PG', 'PG-13', 'TV-Y', nan,
#        'TV-Y7', 'TV-G', 'NC-17', 'G', 'TV-Y7-FV'], dtype=object)

# %% [markdown]
# # movies with TV-14 of Horror genres release after 2000

# %%
data1[((data1['type']=='MOVIE') & (data1['age_certification']=='PG-13')) & (data1['genres'].str.contains('horror', na=False))]
# Out:
#              id                                     title   type  \
# 2598    tm36606                               Cloverfield  MOVIE
# 2623    tm90452                              Troll Hunter  MOVIE
# 2771    tm73706                  Netherbeast Incorporated  MOVIE
# 2776    tm24088                             Scary Movie 4  MOVIE
# 3029    tm39304                          You Belong to Me  MOVIE
# 3046    tm37096                                 Bacterium  MOVIE
# 3181   tm106404                                  Venomous  MOVIE
# 3206   tm143319                     The Turn of the Screw  MOVIE
# 3264    tm41879                                    Spirit  MOVIE
# 3279    tm77257                            Shadow Puppets  MOVIE
# 3301    tm72046                        Dragon Wars: D-War  MOVIE
# 3396    tm58040                           Dracula's Guest  MOVIE
# 3484   tm104333                                 Megaconda  MOVIE
# ...

# %% [markdown]
# #there are 40 movies of PG-13 certified movies of Horror Genres

# %%
data1[((data1['type']=='SHOW') & (data1['age_certification']=='TV-MA')) & (data1['release_year']>=2023)]
# Out:
#              id                              title  type  \
# 10819  ts201838                     The Consultant  SHOW
# 10820  ts311396        Anne Rice's Mayfair Witches  SHOW
# 10830  ts312462       The Head of Joaquín Murrieta  SHOW
# 10843  ts379654  The Challenge: World Championship  SHOW
#
#                                              description  release_year  \
# 10819  A twisted comedic thriller series that explore...          2023
# 10820  An intuitive young neurosurgeon discovers that...          2023
# 10830  Greed took over California because of the gold...          2023
# 10843  Follow previous winners of The Challenge as th...          2023
#
#       age_certification  runtime                                   genres  \
# 10819             TV-MA       32          ['comedy', 'drama', 'thriller']
# 10820             TV-MA       44  ['scifi', 'drama', 'fantasy', 'horror']
# 10830             TV-MA       39           ['drama', 'western', 'action']
# ...

# %%
data1['runtime'].max()
# Out:
# 549

# %%
data1['runtime'].min()
# Out:
# 1

# %%
data1['runtime'].mean()
# Out:
# 85.84887227113738

# %%
data9=data[data['release_year']>=2000]
data9.shape
# Out:
# (8369, 15)

# %%
df=data9[data9['type']=='SHOW']

# %%
df.production_countries.value_counts()
# Out:
# ['US']                460
# ['GB']                201
# ['JP']                101
# []                     96
# ['CN']                 96
#                      ...
# ['NO']                  1
# ['EG', 'GB']            1
# ['MY']                  1
# ['CH', 'US', 'FR']      1
# ['NG']                  1
# Name: production_countries, Length: 82, dtype: int64

# %%
data.sort_values(by='release_year',ascending=False)
# Out:
#               id                              title   type  \
# 10872  tm1297385                           Chapelle  MOVIE
# 10845   ts363288                         El Colapso   SHOW
# 10843   ts379654  The Challenge: World Championship   SHOW
# 10842   ts369924          LOL: Qui Rira Le Dernier?   SHOW
# 10841   ts365330               Cinema Marte Dum Tak   SHOW
# ...          ...                                ...    ...
# 900     tm702575           The Legend of Snow White  MOVIE
# 489     tm134555                The Thundering Herd  MOVIE
# 516     tm162886           The Patchwork Girl of Oz  MOVIE
# 348      tm23348                     Joan the Woman  MOVIE
# 371      tm17827       From the Manger to the Cross  MOVIE
#
#                                              description  release_year  \
# 10872  In the streets of North Paris, in a famous ghe...          2023
# 10845  It tells from the point of view of a diverse g...          2023
# ...

# %%
data9[((data9['type']=='SHOW') & (data9['genres'].str.contains('drama', na=False))) | ((data9['type']=='MOVIE') & (data9['genres'].str.contains('family', na=False)))]
# Out:
#              id                          title   type  \
# 2058    ts21034                       Inuyasha   SHOW
# 2145    tm26137                       Snow Day  MOVIE
# 2266    tm23459           Pokémon 3: The Movie  MOVIE
# 2373    tm19145                Wilderness Love  MOVIE
# 2462    tm21231                          Utsab  MOVIE
# ...         ...                            ...    ...
# 10845  ts363288                     El Colapso   SHOW
# 10846  ts381882                          Dudes   SHOW
# 10856  ts356296  Happy Family Conditions Apply   SHOW
# 10857  ts379207                   Engga Hostel   SHOW
# 10867  ts199693                            A2Z   SHOW
#
#                                              description  release_year  \
# 2058   A teenage girl periodically travels back in ti...          2000
# 2145   When an entire town in upstate New York is clo...          2000
# 2266   When Molly Hale's sadness of her father's disa...          2000
# ...
